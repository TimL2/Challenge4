# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_data = Path('Resources/whale_returns.csv')
whale_df = pd.read_csv(whale_data, index_col='Date', infer_datetime_format=True, parse_dates=True)
whale_df = whale_df.sort_index(axis=0)
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df.dropna(inplace=True)
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_data = Path("Resources/algo_returns.csv")
algo_df = pd.read_csv(algo_data, index_col="Date", infer_datetime_format=True, parse_dates=True)
algo_df = algo_df.sort_index(axis=0)
algo_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df.dropna(inplace=True)
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_data = Path("Resources/sp500_history.csv")
sp500_df = pd.read_csv(sp500_data, index_col="Date", infer_datetime_format=True, parse_dates=True)
sp500_df.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Check Data Types
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
#sp500_df.replace({'Close': {'$': ''}})
sp500_df['Close'] = sp500_df['Close'].str.replace('$','')
# Out:
# C:\Users\tjfoo\AppData\Local\Temp\ipykernel_26680\658492902.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sp500_df['Close'] = sp500_df['Close'].str.replace('$','')

# %%
sp500_df = sp500_df.astype({'Close': 'float'})

# %%
# Calculate Daily Returns
sp500_returns = sp500_df.pct_change()
sp500_returns.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
# Drop nulls
sp500_returns.dropna(inplace=True)

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_returns.rename(columns = {'Close':'SP500 Return'}, inplace = True)
sp500_returns.head()
# Out:
#             SP500 Return
# Date
# 2019-04-22     -0.008764
# 2019-04-18     -0.001011
# 2019-04-17     -0.001577
# 2019-04-16      0.002279
# 2019-04-15     -0.000509

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combined_df = pd.concat([whale_df, algo_df, sp500_returns], axis='columns', join='inner')
combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  SP500 Return
# Date
# 2015-03-03 -0.000949      0.004408
# 2015-03-04  0.002416     -0.001195
# 2015-03-05  0.004323      0.014378
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_df.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
combined_returns = (1+combined_df).cumprod() -1
combined_returns
# Plot cumulative returns
combined_returns.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_df.boxplot(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
combined_std = combined_df.std()
combined_std.head(10)
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# SP500 Return                   0.008587
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
sp500_std = combined_df['SP500 Return'].std()
print(sp500_std)

# Determine which portfolios are riskier than the S&P 500
combined_std > sp500_std
# Out:
# 0.00858688974707399
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# SP500 Return                   False
# dtype: bool

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
combined_std_annual = combined_df.std() * np.sqrt(252)
combined_std_annual.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
combined_rolling_std = combined_df.rolling(window=21).std()
# Plot the rolling standard deviation
combined_rolling_std.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation = combined_returns.corr()
# Display de correlation matrix
correlation.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
combined_returns['rolling cov'] = combined_returns['Algo 1'].rolling(window=60).cov(combined_returns['SP500 Return'])
# Calculate variance of S&P 500
combined_returns['rolling var'] = combined_returns['SP500 Return'].rolling(window=60).var()
# Computing beta
combined_returns['rolling beta'] = combined_returns['rolling cov']/combined_returns['rolling var']
# Plot beta trend
combined_returns['rolling beta'].plot(figsize = (20,10), title = 'Algo 1 Beta')
# Out:
# <AxesSubplot:title={'center':'Algo 1 Beta'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
#combined_returns.drop(columns=['rolling cov','rolling var','rolling beta'], inplace=True)
combined_df.ewm(halflife=21, adjust = True).std()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                        NaN                 NaN
# 2015-03-04                   0.002472            0.005814
# 2015-03-05                   0.002677            0.004968
# 2015-03-06                   0.005349            0.004615
# 2015-03-09                   0.004638            0.004471
# ...                               ...                 ...
# 2019-04-15                   0.007755            0.006960
# 2019-04-16                   0.007632            0.006846
# 2019-04-17                   0.007547            0.006846
# 2019-04-18                   0.007424            0.006737
# 2019-04-22                   0.007336            0.006764
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                          NaN                     NaN       NaN
# 2015-03-04                     0.001441                0.007624  0.004700
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharp_ratio = (combined_df.mean() * 252) / (combined_df.std() * np.sqrt(252))
sharp_ratio
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# Algo 2                         0.484334
# SP500 Return                  -0.518582
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharp_ratio.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
penn_data = Path('Resources/penn.csv')
penn_df = pd.read_csv(penn_data, index_col='Date', infer_datetime_format=True, parse_dates=True)
penn_df = penn_df.sort_index(axis=0)
penn_df.dropna(inplace=True)
penn_df.rename(columns = {'Close':'PENN'}, inplace = True)
penn_df.head()
# Out:
#                       PENN
# Date
# 2021-07-22 16:00:00  72.03
# 2021-07-23 16:00:00  70.33
# 2021-07-26 16:00:00  72.93
# 2021-07-27 16:00:00  71.78
# 2021-07-28 16:00:00  72.08

# %%
# Reading data from 2nd stock
vlo_data = Path('Resources/vlo.csv')
vlo_df = pd.read_csv(vlo_data, index_col='Date', infer_datetime_format=True, parse_dates=True)
vlo_df = vlo_df.sort_index(axis=0)
vlo_df.dropna(inplace=True)
vlo_df.rename(columns = {'Close':'VLO'}, inplace = True)
vlo_df.head()
# Out:
#                        VLO
# Date
# 2021-07-22 16:00:00  63.48
# 2021-07-23 16:00:00  63.71
# 2021-07-26 16:00:00  65.54
# 2021-07-27 16:00:00  65.58
# 2021-07-28 16:00:00  67.30

# %%
# Reading data from 3rd stock
bby_data = Path('Resources/bby.csv')
bby_df = pd.read_csv(bby_data, index_col='Date', infer_datetime_format=True, parse_dates=True)
bby_df = bby_df.sort_index(axis=0)
bby_df.dropna(inplace=True)
bby_df.rename(columns = {'Close':'BBY'}, inplace = True)
bby_df.head()
# Out:
#                         BBY
# Date
# 2021-07-22 16:00:00  109.98
# 2021-07-23 16:00:00  113.28
# 2021-07-26 16:00:00  114.83
# 2021-07-27 16:00:00  114.36
# 2021-07-28 16:00:00  113.06

# %%
# Combine all stocks in a single DataFrame
combined_df2 = pd.concat([penn_df, vlo_df, bby_df], axis='columns', join='inner')
combined_df2.head()
# Out:
#                       PENN    VLO     BBY
# Date
# 2021-07-22 16:00:00  72.03  63.48  109.98
# 2021-07-23 16:00:00  70.33  63.71  113.28
# 2021-07-26 16:00:00  72.93  65.54  114.83
# 2021-07-27 16:00:00  71.78  65.58  114.36
# 2021-07-28 16:00:00  72.08  67.30  113.06

# %%
# Reset Date index
#combined_df2.index = combined_df2.index.date

# %%
# Reorganize portfolio data by having a column per symbol
combined_df2.head()
# Out:
#                       PENN    VLO     BBY
# Date
# 2021-07-22 16:00:00  72.03  63.48  109.98
# 2021-07-23 16:00:00  70.33  63.71  113.28
# 2021-07-26 16:00:00  72.93  65.54  114.83
# 2021-07-27 16:00:00  71.78  65.58  114.36
# 2021-07-28 16:00:00  72.08  67.30  113.06

# %%
# Calculate daily returns
combined_df2_returns = combined_df2.pct_change()
# Drop NAs
combined_df2_returns.dropna(inplace = True)
# Display sample data
combined_df2_returns.head()
# Out:
#                          PENN       VLO       BBY
# Date
# 2021-07-23 16:00:00 -0.023601  0.003623  0.030005
# 2021-07-26 16:00:00  0.036969  0.028724  0.013683
# 2021-07-27 16:00:00 -0.015769  0.000610 -0.004093
# 2021-07-28 16:00:00  0.004179  0.026228 -0.011368
# 2021-07-29 16:00:00 -0.033990  0.005052  0.010614

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
combined_df2_weight_return = combined_df2_returns.dot(weights)
# Display sample data
combined_df2_weight_return.head()
# Out:
# Date
# 2021-07-23 16:00:00    0.003342
# 2021-07-26 16:00:00    0.026458
# 2021-07-27 16:00:00   -0.006417
# 2021-07-28 16:00:00    0.006346
# 2021-07-29 16:00:00   -0.006108
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
combined_all_df = pd.concat([combined_df, combined_df2_weight_return], axis='columns', join='outer')
combined_all_df = combined_all_df.rename(columns = {0: 'My Portfolio'})
combined_all_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  SP500 Return  My Portfolio
# Date
# 2015-03-03 -0.000949      0.004408           NaN
# 2015-03-04  0.002416     -0.001195           NaN
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
print('no dates overlap between old and new dataframes as the instructions state to pull 1 years historical data for the new portfolio')
combined_all_df.dropna(inplace=True)
# Out:
# no dates overlap between old and new dataframes as the instructions state to pull 1 years historical data for the new portfolio

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
combined_df2_weight_return.std()
# Out:
# 0.021890573112415736

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
combined_df2_weight_return_std = combined_df2_weight_return.rolling(window=21).std()
# Plot rolling standard deviation
combined_df2_weight_return_std.plot(figsize=(25,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
combined_df2_returns.corr()
# Out:
#           PENN       VLO       BBY
# PENN  1.000000  0.239217  0.365179
# VLO   0.239217  1.000000  0.098491
# BBY   0.365179  0.098491  1.000000

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
# Calculate covariance of a single portfolio
combined_all_df['rolling cov'] = combined_all_df['My Portfolio'].rolling(window=60).cov(combined_all_df['SP500 Return'])
# Calculate variance of S&P 500
combined_all_df['rolling var'] = combined_all_df['SP500 Return'].rolling(window=60).var()
# Computing beta
combined_all_df['rolling beta'] = combined_all_df['rolling cov']/combined_all_df['rolling var']
# Plot beta trend
combined_all_df['rolling beta'].plot(figsize = (20,10), title = 'My Portfolio Beta')
# Out:
# <AxesSubplot:title={'center':'My Portfolio Beta'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
sharp_ratio2 = (combined_all_df.mean() * 252) / (combined_all_df.std() * np.sqrt(252))
sharp_ratio2
# Out:
# SOROS FUND MANAGEMENT LLC     NaN
# PAULSON & CO.INC.             NaN
# TIGER GLOBAL MANAGEMENT LLC   NaN
# BERKSHIRE HATHAWAY INC        NaN
# Algo 1                        NaN
# Algo 2                        NaN
# SP500 Return                  NaN
# My Portfolio                  NaN
# rolling cov                   NaN
# rolling var                   NaN
# rolling beta                  NaN
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharp_ratio2.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
print('My portfolio was far less sucessful, but hard to compare because it instucted to pull the previous year of data so it was totally uncomparable.')
# Out:
# My portfolio was far less sucessful, but hard to compare because it instucted to pull the previous year of data so it was totally uncomparable.
